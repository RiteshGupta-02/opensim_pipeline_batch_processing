# %%
import opensim as osim

# %%
scaleTool = osim.ScaleTool(r"d:\UG_Proj\Human Sitting to Walking Transitions\S01\scale\subject01_Setup_Scale.xml")
iktool = osim.InverseKinematicsTool(r"d:\UG_Proj\Human Sitting to Walking Transitions\S01\IK\ik_setup_S01_stw1.xml")
idtool = osim.InverseDynamicsTool(r"d:\UG_Proj\Human Sitting to Walking Transitions\S01\ID\id_setup_S01_stw1.xml")

sotool = osim.StaticOptimization(r"d:\UG_Proj\Human Sitting to Walking Transitions\model\RajagopalLa2023_LL-stw_adjustedWieghts.osim")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 iktool = osim.InverseKinematicsTool(r"d:\UG_Proj\Human Sitting to Walking Transitions\S01\IK\ik_setup_S01_stw1.xml")
#       3 idtool = osim.InverseDynamicsTool(r"d:\UG_Proj\Human Sitting to Walking Transitions\S01\ID\id_setup_S01_stw1.xml")
# ----> 5 sotool = osim.StaticOptimization(r"d:\UG_Proj\Human Sitting to Walking Transitions\model\RajagopalLa2023_LL-stw_adjustedWieghts.osim")
#
# File c:\Users\gupta\miniconda3\envs\opensim-env\lib\opensim\analyses.py:494, in StaticOptimization.__init__(self, *args)
#     493 def __init__(self, *args):
# --> 494     _analyses.StaticOptimization_swiginit(self, _analyses.new_StaticOptimization(*args))
#
# TypeError: Wrong number or type of arguments for overloaded function 'new_StaticOptimization'.
#   Possible C/C++ prototypes are:
# ...
